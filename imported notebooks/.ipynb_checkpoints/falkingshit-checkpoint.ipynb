# %%
import torch
import torchvision
import random
import numpy as np
import cv2 # Added cv2 import
import os # Added os import

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import os

# IMPORTANT: Update this path if necessary
base_folder = '/cluster/home/sebassm/tdt4265' 
train_img_dir = os.path.join(base_folder, 'images/train')
val_img_dir = os.path.join(base_folder, 'images/valid')
train_label_dir = os.path.join(base_folder, 'labels/train')
val_label_dir = os.path.join(base_folder, 'labels/valid')

# Verify paths exist (optional but recommended)
assert os.path.isdir(train_img_dir), f"Training image directory not found: {train_img_dir}"
assert os.path.isdir(val_img_dir), f"Validation image directory not found: {val_img_dir}"
assert os.path.isdir(train_label_dir), f"Training label directory not found: {train_label_dir}"
assert os.path.isdir(val_label_dir), f"Validation label directory not found: {val_label_dir}"

# %%
from torch.utils.data import Dataset
import cv2
import torch
import os
import numpy as np
import torchvision # Added for fallback transform

class SnowPoleDataset(Dataset):
    def __init__(self, img_dir, label_dir, transforms=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.transforms = transforms
        # Get sorted list of image filenames (assuming common image extensions)
        self.image_files = sorted([f for f in os.listdir(img_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.img_dir, img_name)
        
        # Construct label path
        label_name = os.path.splitext(img_name)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_name)
        
        # Load image
        img = cv2.imread(img_path)
        if img is None:
            # Return None if image cannot be read, DataLoader's collate_fn should handle this
            print(f"Warning: Could not read image: {img_path}. Skipping.")
            return None, None 
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_h, img_w = img.shape[:2]
        
        # Load labels (YOLO format: class x_center y_center width height - normalized)
        boxes = []
        class_labels = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) == 5:
                        class_id, x_center, y_center, width, height = map(float, parts)
                        
                        # Convert YOLO format (normalized) to Pascal VOC (absolute pixels)
                        x_center_abs = x_center * img_w
                        y_center_abs = y_center * img_h
                        width_abs = width * img_w
                        height_abs = height * img_h
                        
                        xmin = x_center_abs - (width_abs / 2)
                        ymin = y_center_abs - (height_abs / 2)
                        xmax = x_center_abs + (width_abs / 2)
                        ymax = y_center_abs + (height_abs / 2)
                        
                        # Clamp coordinates to image bounds
                        xmin = max(0, xmin)
                        ymin = max(0, ymin)
                        xmax = min(img_w, xmax)
                        ymax = min(img_h, ymax)
                        
                        # Ensure box has valid dimensions
                        if xmax > xmin and ymax > ymin:
                           boxes.append([xmin, ymin, xmax, ymax])
                           # Assuming class_id 0 in YOLO corresponds to label 1 (snow pole)
                           class_labels.append(int(class_id) + 1) 
        
        # Convert to initial tensors
        boxes_tensor = torch.as_tensor(boxes, dtype=torch.float32)
        if not boxes:
             boxes_tensor = torch.zeros((0, 4), dtype=torch.float32)
        labels_tensor = torch.as_tensor(class_labels, dtype=torch.int64)

        target = {} # Initialize target dict
        target['boxes'] = boxes_tensor
        target['labels'] = labels_tensor
        # Store image_id as a plain Python integer
        target['image_id'] = int(idx)
        if boxes_tensor.shape[0] > 0:
            area = (boxes_tensor[:, 2] - boxes_tensor[:, 0]) * (boxes_tensor[:, 3] - boxes_tensor[:, 1])
            target['area'] = area
        else:
            target['area'] = torch.zeros((0,), dtype=torch.float32)
        target['iscrowd'] = torch.zeros((boxes_tensor.shape[0],), dtype=torch.int64) # Assume no crowd

        if self.transforms:
            # Prepare data for Albumentations: combine boxes and labels
            bboxes_for_transform = []
            if target['boxes'].shape[0] > 0:
                # Ensure labels are correctly shaped for concatenation
                labels_for_concat = target['labels'].unsqueeze(1).float() # Needs to be float for concat
                # Combine boxes [N, 4] and labels [N, 1] -> [N, 5]
                combined = torch.cat((target['boxes'], labels_for_concat), dim=1)
                bboxes_for_transform = combined.tolist() # Albumentations often prefers lists

            try:
                # Pass combined bboxes with labels
                sample = self.transforms(image=img, bboxes=bboxes_for_transform)
                img = sample['image']
                
                # Process transformed bboxes+labels
                transformed_bboxes_with_labels = sample['bboxes']
                if len(transformed_bboxes_with_labels) > 0:
                    # Convert back to tensor and separate
                    transformed_tensor = torch.as_tensor(transformed_bboxes_with_labels, dtype=torch.float32)
                    target['boxes'] = transformed_tensor[:, :4]
                    target['labels'] = transformed_tensor[:, 4].to(torch.int64) # Convert label back to int64
                    # Recalculate area
                    target['area'] = (target['boxes'][:, 2] - target['boxes'][:, 0]) * (target['boxes'][:, 3] - target['boxes'][:, 1])
                else: # Handle case where all boxes are removed
                    target['boxes'] = torch.zeros((0, 4), dtype=torch.float32)
                    target['labels'] = torch.zeros((0,), dtype=torch.int64)
                    target['area'] = torch.zeros((0,), dtype=torch.float32)
                target['iscrowd'] = torch.zeros((target['boxes'].shape[0],), dtype=torch.int64)
                
            except (ValueError, TypeError) as e: # Catch TypeError as well, just in case
                print(f"Error during transform for image {img_path}: {e}")
                print(f"Original boxes: {target['boxes']}")
                print(f"Data passed to transform - bboxes_for_transform: {bboxes_for_transform}")
                # Fallback: Return image as tensor without Albumentations transform, keep original target
                # This might cause issues if ToTensorV2 was the only way to get a tensor
                try:
                    img = torchvision.transforms.functional.to_tensor(img)
                except Exception as tensor_err:
                    print(f"  Additionally failed to convert image to tensor: {tensor_err}")
                    return None, None # Skip this sample entirely if conversion fails
                # Keep original target, but ensure types are correct
                target['boxes'] = target['boxes'].to(torch.float32)
                target['labels'] = target['labels'].to(torch.int64)
                # Ensure area and iscrowd match potentially empty boxes
                if target['boxes'].shape[0] == 0:
                    target['area'] = torch.zeros((0,), dtype=torch.float32)
                    target['iscrowd'] = torch.zeros((0,), dtype=torch.int64)
                else:
                     target['area'] = (target['boxes'][:, 2] - target['boxes'][:, 0]) * (target['boxes'][:, 3] - target['boxes'][:, 1])
                     target['iscrowd'] = torch.zeros((target['boxes'].shape[0],), dtype=torch.int64)
                print("  -> Returning image tensor with original target due to transform error.")

        # Ensure final target tensors have correct types even if no transforms or if fallback occurred
        target['boxes'] = target['boxes'].to(torch.float32)
        target['labels'] = target['labels'].to(torch.int64)

        # Final check for valid target structure before returning
        if not isinstance(target.get('boxes'), torch.Tensor) or not isinstance(target.get('labels'), torch.Tensor):
            print(f"Warning: Invalid target structure for image {img_path}. Skipping.")
            return None, None
            
        return img, target

    def __len__(self):
        return len(self.image_files)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2 # Ensure cv2 is imported if used in transforms like Rotate

train_transform = A.Compose([
    # A.RandomSizedBBoxSafeCrop(height=512, width=512, erosion_rate=0.2, p=0.5), # Example: Crop that tries to keep boxes
    A.RandomBrightnessContrast(p=0.3),
    A.Rotate(limit=5, p=0.5, border_mode=cv2.BORDER_CONSTANT), # Added border_mode
    # A.VerticalFlip(p=0.2), # Optional vertical flip
    A.HorizontalFlip(p=0.5),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Standard ImageNet normalization
    ToTensorV2(),
], bbox_params=A.BboxParams(format='pascal_voc')) # Removed label_fields

# Define validation transforms (only normalization and ToTensor)
val_transform = A.Compose([
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
], bbox_params=A.BboxParams(format='pascal_voc')) # Removed label_fields
# Out:
# /cluster/home/sebassm/.local/lib/python3.10/site-packages/albumentations/core/composition.py:250: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

def get_model(num_classes):
    # Load a model pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=torchvision.models.detection.FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
    
    # Get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # Replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    return model

# num_classes includes background, so 1 class (snow pole) + background = 2
model = get_model(num_classes=2)

# %%
# Install pycocotools for evaluation
# !pip install pycocotools --quiet
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import evaluation utilities
# NOTE: You might need to copy the relevant code from 
# torchvision.references.detection.engine and torchvision.references.detection.coco_utils
# into this cell or ensure they are importable in your environment.
# For example:
# from engine import evaluate
# import utils 
# Placeholder: Assume 'evaluate' function is available
try:
    # Attempt to import from a local copy or installed reference scripts
    from engine import evaluate 
    import utils # coco_utils often aliased as utils
    print("Successfully imported evaluation utilities.")
except ImportError:
    print("WARNING: Could not import evaluation utilities (engine.py, utils.py/coco_utils.py). ")
    print("Evaluation step will be skipped. Please ensure these files are available.")
    # Define a dummy evaluate function to avoid errors later
    def evaluate(model, data_loader, device):
        print("Evaluation skipped: Utilities not found.")
        return None # Or return dummy stats
# Out:
# Successfully imported evaluation utilities.

# %%
from torch.utils.data import DataLoader # Import DataLoader
# Import the evaluate function we defined/imported earlier
# from engine import evaluate # Assuming it's available

# Define training parameters and dataloaders
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
if device.type == 'cuda':
    device = torch.device("cuda:1")
model.to(device)
num_epochs = 10 # Example: Set number of epochs
batch_size = 32 # Adjust batch size based on GPU memory
num_workers = 4 # Adjust based on your system

# --- Instantiate Datasets ---
train_dataset = SnowPoleDataset(img_dir=train_img_dir, label_dir=train_label_dir, transforms=train_transform)
val_dataset = SnowPoleDataset(img_dir=val_img_dir, label_dir=val_label_dir, transforms=val_transform)

# --- Define Collate Function ---
def collate_fn(batch):
    # Filter out samples where __getitem__ returned (None, None)
    batch = [(img, tgt) for img, tgt in batch if img is not None and tgt is not None]
    if not batch: # If the whole batch is invalid
        # Return empty tuples to signify an empty batch
        return ((), ()) 
    return tuple(zip(*batch))

# --- Instantiate DataLoaders ---
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=num_workers, collate_fn=collate_fn)
# --- End Data Loading ---

# Construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# And a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=15, # Adjust step size
                                               gamma=0.1) # Adjust gamma

print(f"Starting Training on {device}...")
print(f"Training samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}")

train_losses = []
val_map_50_95 = []
val_map_50 = []
val_ar = []
val_p = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    batches_processed = 0 # Keep track of batches successfully processed
    
    # --- Training Loop ---
    for i, batch_data in enumerate(train_loader): 
        # Check if collate_fn returned indication of an empty batch
        if batch_data == ((), ()):
            print(f"Skipping batch {i} due to empty batch after filtering.")
            continue
            
        images, targets = batch_data
        
        # Ensure images and targets are lists/tuples (collate_fn returns tuple of tuples)
        if not isinstance(images, (list, tuple)) or not isinstance(targets, (list, tuple)):
             print(f"Skipping batch {i} due to unexpected data format from collate_fn.")
             continue
             
        images = list(image.to(device) for image in images)
        # Move only tensor values in targets to the device
        targets = [{k: v.to(device) if isinstance(v, torch.Tensor) else v for k, v in t.items()} for t in targets]

        # Check for empty targets (e.g., if all boxes were removed by transform)
        valid_targets = []
        valid_indices = []
        for idx, t in enumerate(targets):
            # Check if 'boxes' key exists and has items
            if 'boxes' in t and t['boxes'].shape[0] > 0:
                valid_targets.append(t)
                valid_indices.append(idx)
                
        if not valid_targets:
            print(f"Skipping batch {i} due to empty targets after transformations or errors.")
            continue
            
        # Filter images corresponding to valid targets
        images = [images[idx] for idx in valid_indices]
        # Targets are already filtered
        targets = valid_targets 

        # Faster R-CNN returns a dict of losses in train mode
        try:
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
        except Exception as model_err:
            print(f"Error during model forward/loss calculation for batch {i}: {model_err}")
            # Optionally print shapes or inspect data
            print(f"  Image shapes: {[img.shape for img in images]}")
            print(f"  Target sample: {targets[0] if targets else 'No targets'}")
            continue # Skip this batch

        # Check for NaN or inf losses
        if not torch.isfinite(losses):
            print(f"WARNING: Non-finite loss detected: {losses.item()}. Skipping batch {i}.")
            print(f"Loss dict: {loss_dict}")
            continue

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        epoch_loss += losses.item()
        batches_processed += 1 # Increment successful batch count
        
        if (i + 1) % 50 == 0: # Print progress every 50 batches
             print(f"  Batch {i+1}/{len(train_loader)}, Batch Loss: {losses.item():.4f}")
    # --- End Training Loop ---
    
    # Update the learning rate
    lr_scheduler.step()

    # Calculate average loss based on successfully processed batches
    if batches_processed > 0:
        avg_epoch_loss = epoch_loss / batches_processed
        train_losses.append(avg_epoch_loss)
        print(f"Epoch {epoch+1}/{num_epochs}, Average Training Loss: {avg_epoch_loss:.4f}")
    else:
        train_losses.append(float('nan')) # Append NaN if no batches were processed
        print(f"Epoch {epoch+1}/{num_epochs}, No batches processed successfully in training.")

    print(f"Running Validation for Epoch {epoch+1}...")
    current_map_50_95 = 0.0 # Default values if evaluation fails
    current_map_50 = 0.0
    current_ar = 0.0
    current_p = 0.0
    if 'evaluate' in globals() and callable(evaluate): # Check if evaluate is defined and callable
        # Ensure model is in evaluation mode for validation
        model.eval()
        coco_evaluator = evaluate(model, val_loader, device=device)
        if coco_evaluator and hasattr(coco_evaluator, 'coco_eval') and 'bbox' in coco_evaluator.coco_eval:
            stats = coco_evaluator.coco_eval['bbox'].stats
            current_map_50_95 = stats[0] # AP@0.50:0.95
            current_map_50 = stats[1]    # AP@0.50
            current_ar = stats[8]       # AR@0.50:0.95
            print(f"Validation Epoch {epoch+1} - mAP@0.50:0.95: {current_map_50_95:.4f}, mAP@0.50: {current_map_50:.4f}")
        else:
            print("Validation evaluation did not produce expected results.")
    else:
        print("Skipping validation because evaluate function is not available or callable.")

    val_map_50_95.append(current_map_50_95)
    val_map_50.append(current_map_50)
    val_ar.append(current_ar)
    

print("Training Finished.")

# --- Run Final Validation After Training ---
print("Running Final Validation...")
if 'evaluate' in globals():
    coco_evaluator = evaluate(model, val_loader, device=device)
    if coco_evaluator:
        stats = coco_evaluator.coco_eval['bbox'].stats
        print(f"Validation AP@0.50:0.95: {stats[0]:.4f}")
        print(f"Validation AP@0.50:      {stats[1]:.4f}")
        # Print other stats if desired
        # print(f"Validation AP@0.75:      {stats[2]:.4f}")
        # print(f"Validation AP (small):   {stats[3]:.4f}")
        # print(f"Validation AP (medium):  {stats[4]:.4f}")
        # print(f"Validation AP (large):   {stats[5]:.4f}")
else:
    print("Skipping final validation because evaluate function is not defined.")
# --- End Final Validation ---
# Out:
# Starting Training on cuda:1...
# Training samples: 1367, Validation samples: 390
# Epoch 1/10, Average Training Loss: 0.1320
# Running Validation for Epoch 1...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:02:06  model_time: 0.1268 (0.1268)  evaluator_time: 0.0259 (0.0259)  time: 0.3234  data: 0.1677  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0343 (0.0347)  evaluator_time: 0.0013 (0.0015)  time: 0.0392  data: 0.0024  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0338 (0.0342)  evaluator_time: 0.0011 (0.0014)  time: 0.0378  data: 0.0021  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0334 (0.0340)  evaluator_time: 0.0011 (0.0013)  time: 0.0373  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0330 (0.0338)  evaluator_time: 0.0013 (0.0013)  time: 0.0368  data: 0.0020  max mem: 86
# Test: Total time: 0:00:15 (0.0386 s / it)
# Averaged stats: model_time: 0.0330 (0.0338)  evaluator_time: 0.0013 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3826
# Stat 1: 0.8632
# Stat 2: 0.2536
# Stat 3: 0.3826
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2483
# Stat 7: 0.4772
# Stat 8: 0.4772
# Stat 9: 0.4772
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 1 - mAP@0.50:0.95: 0.3826, mAP@0.50: 0.8632
# Epoch 2/10, Average Training Loss: 0.1330
# Running Validation for Epoch 2...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:27  model_time: 0.0496 (0.0496)  evaluator_time: 0.0025 (0.0025)  time: 0.2236  data: 0.1700  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0336 (0.0351)  evaluator_time: 0.0011 (0.0012)  time: 0.0387  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0337 (0.0351)  evaluator_time: 0.0011 (0.0012)  time: 0.0389  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0336 (0.0350)  evaluator_time: 0.0011 (0.0012)  time: 0.0386  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0336 (0.0350)  evaluator_time: 0.0013 (0.0012)  time: 0.0384  data: 0.0021  max mem: 86
# Test: Total time: 0:00:15 (0.0395 s / it)
# Averaged stats: model_time: 0.0336 (0.0350)  evaluator_time: 0.0013 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3630
# Stat 1: 0.8571
# Stat 2: 0.2025
# Stat 3: 0.3630
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2411
# Stat 7: 0.4640
# Stat 8: 0.4640
# Stat 9: 0.4640
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 2 - mAP@0.50:0.95: 0.3630, mAP@0.50: 0.8571
# Epoch 3/10, Average Training Loss: 0.1311
# Running Validation for Epoch 3...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:24  model_time: 0.0474 (0.0474)  evaluator_time: 0.0025 (0.0025)  time: 0.2173  data: 0.1663  max mem: 86
# Test:  [100/390]  eta: 0:00:13  model_time: 0.0334 (0.0396)  evaluator_time: 0.0012 (0.0012)  time: 0.0663  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0338 (0.0369)  evaluator_time: 0.0012 (0.0013)  time: 0.0378  data: 0.0021  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0334 (0.0358)  evaluator_time: 0.0011 (0.0012)  time: 0.0372  data: 0.0020  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0334 (0.0352)  evaluator_time: 0.0012 (0.0012)  time: 0.0373  data: 0.0021  max mem: 86
# Test: Total time: 0:00:15 (0.0397 s / it)
# Averaged stats: model_time: 0.0334 (0.0352)  evaluator_time: 0.0012 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3999
# Stat 1: 0.8754
# Stat 2: 0.2938
# Stat 3: 0.3999
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2539
# Stat 7: 0.4809
# Stat 8: 0.4809
# Stat 9: 0.4809
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 3 - mAP@0.50:0.95: 0.3999, mAP@0.50: 0.8754
# Epoch 4/10, Average Training Loss: 0.1313
# Running Validation for Epoch 4...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:26  model_time: 0.0467 (0.0467)  evaluator_time: 0.0026 (0.0026)  time: 0.2218  data: 0.1713  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0339 (0.0353)  evaluator_time: 0.0012 (0.0013)  time: 0.0381  data: 0.0022  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0339 (0.0347)  evaluator_time: 0.0013 (0.0013)  time: 0.0390  data: 0.0023  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0341 (0.0345)  evaluator_time: 0.0011 (0.0013)  time: 0.0379  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0336 (0.0343)  evaluator_time: 0.0012 (0.0013)  time: 0.0378  data: 0.0021  max mem: 86
# Test: Total time: 0:00:15 (0.0389 s / it)
# Averaged stats: model_time: 0.0336 (0.0343)  evaluator_time: 0.0012 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.4018
# Stat 1: 0.8735
# Stat 2: 0.2906
# Stat 3: 0.4018
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2616
# Stat 7: 0.4895
# Stat 8: 0.4895
# Stat 9: 0.4895
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 4 - mAP@0.50:0.95: 0.4018, mAP@0.50: 0.8735
# Epoch 5/10, Average Training Loss: 0.1317
# Running Validation for Epoch 5...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:24  model_time: 0.0454 (0.0454)  evaluator_time: 0.0025 (0.0025)  time: 0.2176  data: 0.1687  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0335 (0.0337)  evaluator_time: 0.0012 (0.0012)  time: 0.0374  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0331 (0.0336)  evaluator_time: 0.0011 (0.0012)  time: 0.0373  data: 0.0021  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0334 (0.0336)  evaluator_time: 0.0012 (0.0012)  time: 0.0373  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0330 (0.0335)  evaluator_time: 0.0012 (0.0012)  time: 0.0368  data: 0.0020  max mem: 86
# Test: Total time: 0:00:14 (0.0379 s / it)
# Averaged stats: model_time: 0.0330 (0.0335)  evaluator_time: 0.0012 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.304
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.4017
# Stat 1: 0.8706
# Stat 2: 0.3036
# Stat 3: 0.4017
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2612
# Stat 7: 0.4866
# Stat 8: 0.4866
# Stat 9: 0.4866
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 5 - mAP@0.50:0.95: 0.4017, mAP@0.50: 0.8706
# Epoch 6/10, Average Training Loss: 0.1313
# Running Validation for Epoch 6...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:26  model_time: 0.0450 (0.0450)  evaluator_time: 0.0027 (0.0027)  time: 0.2206  data: 0.1718  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0337 (0.0338)  evaluator_time: 0.0014 (0.0013)  time: 0.0381  data: 0.0023  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0335 (0.0337)  evaluator_time: 0.0012 (0.0013)  time: 0.0378  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0337 (0.0339)  evaluator_time: 0.0011 (0.0013)  time: 0.0379  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0336 (0.0338)  evaluator_time: 0.0013 (0.0013)  time: 0.0380  data: 0.0021  max mem: 86
# Test: Total time: 0:00:14 (0.0384 s / it)
# Averaged stats: model_time: 0.0336 (0.0338)  evaluator_time: 0.0013 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3929
# Stat 1: 0.8712
# Stat 2: 0.2607
# Stat 3: 0.3929
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2553
# Stat 7: 0.4792
# Stat 8: 0.4792
# Stat 9: 0.4792
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 6 - mAP@0.50:0.95: 0.3929, mAP@0.50: 0.8712
# Epoch 7/10, Average Training Loss: 0.1298
# Running Validation for Epoch 7...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:26  model_time: 0.0463 (0.0463)  evaluator_time: 0.0024 (0.0024)  time: 0.2205  data: 0.1707  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0333 (0.0340)  evaluator_time: 0.0012 (0.0012)  time: 0.0372  data: 0.0020  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0336 (0.0338)  evaluator_time: 0.0012 (0.0012)  time: 0.0381  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0336 (0.0338)  evaluator_time: 0.0011 (0.0012)  time: 0.0376  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0339 (0.0339)  evaluator_time: 0.0012 (0.0012)  time: 0.0380  data: 0.0022  max mem: 86
# Test: Total time: 0:00:14 (0.0384 s / it)
# Averaged stats: model_time: 0.0339 (0.0339)  evaluator_time: 0.0012 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.4012
# Stat 1: 0.8759
# Stat 2: 0.3104
# Stat 3: 0.4013
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2588
# Stat 7: 0.4858
# Stat 8: 0.4858
# Stat 9: 0.4858
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 7 - mAP@0.50:0.95: 0.4012, mAP@0.50: 0.8759
# Epoch 8/10, Average Training Loss: 0.1278
# Running Validation for Epoch 8...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:26  model_time: 0.0456 (0.0456)  evaluator_time: 0.0026 (0.0026)  time: 0.2216  data: 0.1724  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0337 (0.0340)  evaluator_time: 0.0011 (0.0012)  time: 0.0375  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0341 (0.0340)  evaluator_time: 0.0011 (0.0012)  time: 0.0382  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0335 (0.0341)  evaluator_time: 0.0011 (0.0012)  time: 0.0375  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0335 (0.0341)  evaluator_time: 0.0012 (0.0012)  time: 0.0374  data: 0.0021  max mem: 86
# Test: Total time: 0:00:15 (0.0386 s / it)
# Averaged stats: model_time: 0.0335 (0.0341)  evaluator_time: 0.0012 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.870
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3979
# Stat 1: 0.8696
# Stat 2: 0.2782
# Stat 3: 0.3979
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2515
# Stat 7: 0.4809
# Stat 8: 0.4809
# Stat 9: 0.4809
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 8 - mAP@0.50:0.95: 0.3979, mAP@0.50: 0.8696
# Epoch 9/10, Average Training Loss: 0.1301
# Running Validation for Epoch 9...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:25  model_time: 0.0473 (0.0473)  evaluator_time: 0.0025 (0.0025)  time: 0.2185  data: 0.1674  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0335 (0.0339)  evaluator_time: 0.0013 (0.0013)  time: 0.0379  data: 0.0023  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0337 (0.0340)  evaluator_time: 0.0011 (0.0013)  time: 0.0380  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0340 (0.0342)  evaluator_time: 0.0012 (0.0013)  time: 0.0390  data: 0.0023  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0329 (0.0342)  evaluator_time: 0.0013 (0.0013)  time: 0.0368  data: 0.0020  max mem: 86
# Test: Total time: 0:00:15 (0.0389 s / it)
# Averaged stats: model_time: 0.0329 (0.0342)  evaluator_time: 0.0013 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3957
# Stat 1: 0.8761
# Stat 2: 0.2820
# Stat 3: 0.3957
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2518
# Stat 7: 0.4802
# Stat 8: 0.4802
# Stat 9: 0.4802
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 9 - mAP@0.50:0.95: 0.3957, mAP@0.50: 0.8761
# Epoch 10/10, Average Training Loss: 0.1306
# Running Validation for Epoch 10...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:25  model_time: 0.0457 (0.0457)  evaluator_time: 0.0024 (0.0024)  time: 0.2184  data: 0.1692  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0335 (0.0339)  evaluator_time: 0.0012 (0.0013)  time: 0.0378  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0339 (0.0338)  evaluator_time: 0.0012 (0.0013)  time: 0.0382  data: 0.0022  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0337 (0.0339)  evaluator_time: 0.0012 (0.0013)  time: 0.0376  data: 0.0021  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0335 (0.0339)  evaluator_time: 0.0013 (0.0013)  time: 0.0376  data: 0.0021  max mem: 86
# Test: Total time: 0:00:14 (0.0384 s / it)
# Averaged stats: model_time: 0.0335 (0.0339)  evaluator_time: 0.0013 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# all stats with labels:
# Stat 0: 0.3854
# Stat 1: 0.8745
# Stat 2: 0.2564
# Stat 3: 0.3854
# Stat 4: -1.0000
# Stat 5: -1.0000
# Stat 6: 0.2513
# Stat 7: 0.4763
# Stat 8: 0.4763
# Stat 9: 0.4763
# Stat 10: -1.0000
# Stat 11: -1.0000
# Validation Epoch 10 - mAP@0.50:0.95: 0.3854, mAP@0.50: 0.8745
# Training Finished.
# Running Final Validation...
# creating index...
# index created!
# Test:  [  0/390]  eta: 0:01:23  model_time: 0.0444 (0.0444)  evaluator_time: 0.0025 (0.0025)  time: 0.2142  data: 0.1661  max mem: 86
# Test:  [100/390]  eta: 0:00:11  model_time: 0.0339 (0.0338)  evaluator_time: 0.0013 (0.0013)  time: 0.0379  data: 0.0021  max mem: 86
# Test:  [200/390]  eta: 0:00:07  model_time: 0.0335 (0.0341)  evaluator_time: 0.0011 (0.0013)  time: 0.0374  data: 0.0021  max mem: 86
# Test:  [300/390]  eta: 0:00:03  model_time: 0.0341 (0.0340)  evaluator_time: 0.0012 (0.0013)  time: 0.0384  data: 0.0022  max mem: 86
# Test:  [389/390]  eta: 0:00:00  model_time: 0.0337 (0.0342)  evaluator_time: 0.0014 (0.0013)  time: 0.0379  data: 0.0021  max mem: 86
# Test: Total time: 0:00:15 (0.0387 s / it)
# Averaged stats: model_time: 0.0337 (0.0342)  evaluator_time: 0.0014 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Validation AP@0.50:0.95: 0.3854
# Validation AP@0.50:      0.8745

# %%
# --- Save the Model ---
model_save_path = os.path.join(base_folder, 'fasterrcnn_snowpole_model.pth')
print(f"Saving model state dictionary to: {model_save_path}")
torch.save(model.state_dict(), model_save_path)
print("Model saved successfully.")
# Out:
# Saving model state dictionary to: /cluster/home/sebassm/tdt4265/fasterrcnn_snowpole_model.pth
# Model saved successfully.

# %% [markdown]
# ## Model Evaluation
#
# The training loop now includes a validation step after each epoch using the `evaluate` function (leveraging `pycocotools`). Standard COCO metrics (like Average Precision) are printed for the validation set.

# %%
# This cell remains empty or can be used for saving the model, etc.

# %%
# Getting precision and recall from the coco_evaluator using `accumulate()` method
if 'coco_evaluator' in globals() and coco_evaluator:
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
# Out:
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000

# %%
# In cell with id: 62a48cc5
# In a new cell after the training cell
import matplotlib.pyplot as plt
import numpy as np # Import numpy for handling potential NaNs

print("Generating training plots...")

epochs = range(1, num_epochs + 1)

# Filter out potential NaN values for plotting if any epoch had zero batches
valid_train_indices = ~np.isnan(train_losses)
valid_epochs_train = np.array(epochs)[valid_train_indices]
valid_train_losses = np.array(train_losses)[valid_train_indices]

plt.figure(figsize=(18, 5)) # Increased figure width for 3 plots

# Plot Training Loss
plt.subplot(1, 3, 1) # Changed to 1 row, 3 columns, 1st plot
if len(valid_epochs_train) > 0:
    plt.plot(valid_epochs_train, valid_train_losses, 'bo-', label='Training Loss')
    plt.title('Training Loss per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
else:
    plt.text(0.5, 0.5, 'No valid training data to plot', horizontalalignment='center', verticalalignment='center')


# Plot Validation mAP
plt.subplot(1, 3, 2) # Changed to 1 row, 3 columns, 2nd plot
plt.plot(epochs, val_map_50_95, 'ro-', label='mAP@0.50:0.95')
plt.plot(epochs, val_map_50, 'go-', label='mAP@0.50')
plt.title('Validation mAP per Epoch')
plt.xlabel('Epoch')
plt.ylabel('mAP')
plt.legend()
plt.grid(True)

# Plot Validation Average Recall
plt.subplot(1, 3, 3) # Changed to 1 row, 3 columns, 3rd plot
plt.plot(epochs, val_ar, 'mo-', label='AR@100')
plt.title('Validation Average Recall per Epoch')
plt.xlabel('Epoch')
plt.ylabel('AR')
plt.legend()
plt.grid(True)


plt.tight_layout()
plt.show()

print("Plotting finished.")
# Out:
# Generating training plots...
# Plotting finished.

# %%
import matplotlib.pyplot as plt # For visualization
import cv2
import numpy as np # Ensure numpy is imported
from albumentations.pytorch import ToTensorV2 # Ensure ToTensorV2 is imported
import albumentations as A # Ensure albumentations is imported

# --- Load a single image for inference ---
# !!! Replace 'path/to/your/test_image.png' with an actual image path !!!
img_path = '/cluster/home/sebassm/tdt4265/images/valid/image_16.png' # Example image path

try:
    img_display = cv2.imread(img_path)
    if img_display is None:
        raise FileNotFoundError(f"Could not read image file: {img_path}")
    img_display = cv2.cvtColor(img_display, cv2.COLOR_BGR2RGB)
except FileNotFoundError as e:
    print(e)
    print("--- Using a dummy white image for visualization structure check --- ")
    # Fallback to a dummy image if the path is invalid, so the rest of the cell can run
    img_display = np.ones((512, 512, 3), dtype=np.uint8) * 255 # White dummy image
    img_tensor = torch.rand(3, 512, 512).to(device) # Dummy tensor
else:
    # Define the same normalization transform used during validation/training
    # Note: No augmentations like flips/rotations here, just normalization and ToTensor
    inference_transform = A.Compose([
        A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ToTensorV2(),
    ])
    # Apply the transform
    img_tensor = inference_transform(image=img_display)['image'].to(device)
# --- End Image Loading ---

# Create dummy data for visualization structure check (REMOVED - replaced by actual loading)
# img_display = np.zeros((512, 512, 3), dtype=np.uint8)
# img_tensor = torch.zeros(3, 512, 512).to(device)

model.eval()
with torch.no_grad():
    # Model expects a list of images
    prediction = model([img_tensor])[0]

print("Prediction:", prediction)

# Draw prediction boxes on the display image
detection_threshold = 0.5 # Lowered threshold slightly for potentially weaker detections
img_with_boxes = img_display.copy()

for box, score, label in zip(prediction['boxes'], prediction['scores'], prediction['labels']):
    if score > detection_threshold:
        # Convert box coordinates to integers
        xmin, ymin, xmax, ymax = map(int, box.cpu().numpy())
        # Draw rectangle (color based on label, e.g., green for snow pole)
        color = (0, 255, 0) if label == 1 else (255, 0, 0) # Green for class 1 (snow pole)
        cv2.rectangle(img_with_boxes, (xmin, ymin), (xmax, ymax), color, 2)
        # Add label and score text
        text = f"Label: {label.item()} Score: {score.item():.2f}"
        cv2.putText(img_with_boxes, text, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

# Display the image with boxes
plt.figure(figsize=(10, 10))
plt.imshow(img_with_boxes)
plt.axis('off')
plt.show()
# Out:
# Prediction: {'boxes': tensor([[344.6663,  95.9943, 354.0831, 127.7981],
#         [556.9455,  83.1024, 566.4659, 125.4756],
#         [198.7082,  88.8025, 206.7334, 128.0000],
#         [804.8950,  91.7280, 813.9417, 128.0000]], device='cuda:1'), 'labels': tensor([1, 1, 1, 1], device='cuda:1'), 'scores': tensor([0.9940, 0.9860, 0.0887, 0.0519], device='cuda:1')}

# %%
# In cell with id: efd2bd37
import os
import cv2
import torch
import albumentations as A
from albumentations.pytorch import ToTensorV2
import time

# --- Configuration ---
test_img_dir = os.path.join(base_folder, 'images/test')
results_dir = os.path.join(base_folder, 'results', 'faster_rcnn_run')
detection_threshold = 0.5 # Confidence threshold for saving predictions
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
if device.type == 'cuda':
    device = torch.device("cuda:1") # Use the second GPU if available
# model.to(device) # Model should already be on device from training, but ensure it is

# Ensure results directory exists
os.makedirs(results_dir, exist_ok=True)

# Define the inference transform (same as validation)
inference_transform = A.Compose([
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# --- Prediction Loop ---
model.to(device) # Ensure model is on the correct device
model.eval()

print(f"Starting prediction on test images in: {test_img_dir}")
print(f"Saving results to: {results_dir}")

test_image_files = sorted([f for f in os.listdir(test_img_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

# --- FPS Tracking Initialization ---
start_time = time.time()
images_processed_count = 0
# ---

with torch.no_grad():
    for i, img_name in enumerate(test_image_files):
        img_path = os.path.join(test_img_dir, img_name)

        # Load image
        img = cv2.imread(img_path)
        if img is None:
            print(f"Warning: Could not read image {img_path}. Skipping.")
            continue
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        H, W = img.shape[:2]

        # Apply transform
        transformed = inference_transform(image=img_rgb)
        img_tensor = transformed['image'].unsqueeze(0).to(device) # Add batch dimension and send to device

        # --- Measure Inference Time (Optional: for per-image timing) ---
        # iter_start_time = time.time()

        # Get prediction
        # Note: Ensure model input is a list/batch, even if it's just one image
        prediction = model(img_tensor)[0]

        # iter_end_time = time.time()
        # print(f"  Inference time for {img_name}: {iter_end_time - iter_start_time:.4f}s")
        # ---

        # Prepare output file path
        txt_filename = os.path.splitext(img_name)[0] + '.txt'
        txt_path = os.path.join(results_dir, txt_filename)

        # Process and save predictions
        with open(txt_path, 'w') as f:
            for box, score, label in zip(prediction['boxes'], prediction['scores'], prediction['labels']):
                if score > detection_threshold:
                    # Convert box from Pascal VOC (xmin, ymin, xmax, ymax) to YOLO format
                    xmin, ymin, xmax, ymax = box.cpu().numpy()

                    # Clamp coordinates to image bounds (important after model prediction)
                    xmin = max(0, xmin)
                    ymin = max(0, ymin)
                    xmax = min(W, xmax)
                    ymax = min(H, ymax)

                    if xmax <= xmin or ymax <= ymin: # Skip invalid boxes
                        continue

                    box_w = xmax - xmin
                    box_h = ymax - ymin
                    x_center = xmin + box_w / 2
                    y_center = ymin + box_h / 2

                    # Normalize
                    x_center_norm = x_center / W
                    y_center_norm = y_center / H
                    width_norm = box_w / W
                    height_norm = box_h / H

                    # Adjust class ID (Faster R-CNN uses 1 for snow pole, YOLO often uses 0)
                    class_id = label.item() - 1
                    confidence = score.item()

                    # Write line: <class_id> <x_center_norm> <y_center_norm> <width_norm> <height_norm> <confidence>
                    f.write(f"{class_id} {x_center_norm:.6f} {y_center_norm:.6f} {width_norm:.6f} {height_norm:.6f} {confidence:.6f}\n")

        images_processed_count += 1 # Increment counter for successfully processed images

        if (i + 1) % 50 == 0:
            print(f"  Processed {i+1}/{len(test_image_files)} images...")

# --- FPS Calculation ---
end_time = time.time()
total_time = end_time - start_time
fps = 0
if total_time > 0:
    fps = images_processed_count / total_time
# ---

print(f"Prediction finished.")
print(f"Processed {images_processed_count} images in {total_time:.2f} seconds.")
print(f"Average Inference Speed: {fps:.2f} FPS")
# Out:
# Starting prediction on test images in: /cluster/home/sebassm/tdt4265/images/test
# Saving results to: /cluster/home/sebassm/tdt4265/results/faster_rcnn_run
#   Processed 50/197 images...
#   Processed 100/197 images...
#   Processed 150/197 images...
# Prediction finished.
# Processed 197 images in 8.98 seconds.
# Average Inference Speed: 21.93 FPS
